# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
df = pd.read_csv("C:\\Users\\ASUS\\data_analyst\\da_project\\se_jobs&salary\\Software_Engineer_Salaries.csv")
df
# Out:
#                            Company  Company Score  \
# 0                         ViewSoft            4.8
# 1                          Workiva            4.3
# 2       Garmin International, Inc.            3.9
# 3                         Snapchat            3.5
# 4    Vitesco Technologies Group AG            3.1
# ..                             ...            ...
# 865                            RXO            NaN
# 866                        Infosys            NaN
# 867                      Medtronic            NaN
# 868                            NaN            NaN
# 869                            NaN            NaN
#
#                                              Job Title  \
# 0                                    Software Engineer
# 1                            Software Support Engineer
# 2                                 C# Software Engineer
# 3    Software Engineer, Fullstack, 1+ Years of Expe...
# 4                                    Software Engineer
# ..                                                 ...
# 865        Software Engineer, Machine Learning Compute
# 866                Software Engineer - 3 (Apache NiFi)
# 867                           Senior Software Engineer
# 868                            Junior Python Developer
# 869       GUI Software Engineer II - Surgical Robotics
#
#                    Location Date                         Salary
# 0              Manassas, VA   8d   $68K - $94K (Glassdoor est.)
# 1                    Remote   2d   $61K - $104K (Employer est.)
# 2                  Cary, NC   2d  $95K - $118K (Glassdoor est.)
# 3           Los Angeles, CA   2d   $97K - $145K (Employer est.)
# 4                Seguin, TX   2d  $85K - $108K (Glassdoor est.)
# ..                      ...  ...                            ...
# 865       San Francisco, CA   6d                            NaN
# 866  Annapolis Junction, MD  18d                            NaN
# 867          Southfield, MI  19d                            NaN
# 868           Charlotte, NC   2d                            NaN
# 869              Boston, MA  10d                            NaN
#
# [870 rows x 6 columns]

# %%
df.shape
# Out:
# (870, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        868 non-null    object
#  1   Company Score  789 non-null    float64
#  2   Job Title      870 non-null    object
#  3   Location       857 non-null    object
#  4   Date           870 non-null    object
#  5   Salary         764 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 40.9+ KB

# %%
df.isnull().sum()
# Out:
# Company            2
# Company Score     81
# Job Title          0
# Location          13
# Date               0
# Salary           106
# dtype: int64

# %%
df.describe()
# Out:
#        Company Score
# count     789.000000
# mean        3.895311
# std         0.524952
# min         1.000000
# 25%         3.600000
# 50%         3.900000
# 75%         4.200000
# max         5.000000

# %%
def job_title(title):
    return re.split(r'\(|-|,', title)[0].strip()

df['Job Title'] = df['Job Title'].apply(job_title)

# %%
df.head(10)
# Out:
#                          Company  Company Score                    Job Title  \
# 0                       ViewSoft            4.8            Software Engineer
# 1                        Workiva            4.3    Software Support Engineer
# 2     Garmin International, Inc.            3.9         C# Software Engineer
# 3                       Snapchat            3.5            Software Engineer
# 4  Vitesco Technologies Group AG            3.1            Software Engineer
# 5                        Spotify            3.9          Backend Engineer II
# 6                          Infor            4.0  Associate Software Engineer
# 7          Amerisoft Corporation            5.0          Software Developers
# 8                          WHOOP            3.3         Software Engineer II
# 9                            PFF            4.2        Sr. Software Engineer
#
#                Location  Date                         Salary
# 0          Manassas, VA    8d   $68K - $94K (Glassdoor est.)
# 1                Remote    2d   $61K - $104K (Employer est.)
# 2              Cary, NC    2d  $95K - $118K (Glassdoor est.)
# 3       Los Angeles, CA    2d   $97K - $145K (Employer est.)
# 4            Seguin, TX    2d  $85K - $108K (Glassdoor est.)
# 5          New York, NY    1d  $123K - $175K (Employer est.)
# 6        Alpharetta, GA    7d   $77K - $94K (Glassdoor est.)
# 7  Farmington Hills, MI  30d+  $71K - $100K (Glassdoor est.)
# 8            Boston, MA   10d  $94K - $148K (Glassdoor est.)
# 9                Remote    1d  $147K - $189K (Employer est.)

# %%
def date_correction(date):
    if 'd' in date:
        return int(date.replace('d', '').replace('+', '').strip())
    
    elif 'h' in date:
        return int(date.replace('h', '').strip())/24
    
    elif 'w' in date:
        return int(date.replace('w', '').strip())/7
    
df['Date'] = df['Date'].apply(date_correction)

# %%
df
# Out:
#                            Company  Company Score                  Job Title  \
# 0                         ViewSoft            4.8          Software Engineer
# 1                          Workiva            4.3  Software Support Engineer
# 2       Garmin International, Inc.            3.9       C# Software Engineer
# 3                         Snapchat            3.5          Software Engineer
# 4    Vitesco Technologies Group AG            3.1          Software Engineer
# ..                             ...            ...                        ...
# 865                            RXO            NaN          Software Engineer
# 866                        Infosys            NaN          Software Engineer
# 867                      Medtronic            NaN   Senior Software Engineer
# 868                            NaN            NaN    Junior Python Developer
# 869                            NaN            NaN   GUI Software Engineer II
#
#                    Location  Date                         Salary
# 0              Manassas, VA   8.0   $68K - $94K (Glassdoor est.)
# 1                    Remote   2.0   $61K - $104K (Employer est.)
# 2                  Cary, NC   2.0  $95K - $118K (Glassdoor est.)
# 3           Los Angeles, CA   2.0   $97K - $145K (Employer est.)
# 4                Seguin, TX   2.0  $85K - $108K (Glassdoor est.)
# ..                      ...   ...                            ...
# 865       San Francisco, CA   6.0                            NaN
# 866  Annapolis Junction, MD  18.0                            NaN
# 867          Southfield, MI  19.0                            NaN
# 868           Charlotte, NC   2.0                            NaN
# 869              Boston, MA  10.0                            NaN
#
# [870 rows x 6 columns]

# %%
def salary_correction(salary):
    salary_range = re.findall(r'\$([\dK]+)', salary )
    salary_info = 'Employer est.' if 'Employer est.' in salary else 'Glassdoor est'
    
#     salary_range = [int(s.replace('K', ''))*1000 for s in salary]
    
    salary_range = [int(s.replace('K', '').replace('$', '').replace(',', '')) * 1000 for s in salary_range]
    
    if len(salary_range) == 2:
        return sum(salary_range)/2, salary_info
    
    else:
        return None, salary_info
    
df['Salary'] = df['Salary'].astype(str)
df[['Annual Salary', 'Estimate Type']] = df['Salary'].apply(lambda x: pd.Series(salary_correction(x)))

df['Employer est'] = df['Estimate Type'] == 'Employer est.'
df['Glassdoor est'] =df['Estimate Type'] == 'Glassdoor est.'

# %%
df.head(10)
# Out:
#                          Company  Company Score                    Job Title  \
# 0                       ViewSoft            4.8            Software Engineer
# 1                        Workiva            4.3    Software Support Engineer
# 2     Garmin International, Inc.            3.9         C# Software Engineer
# 3                       Snapchat            3.5            Software Engineer
# 4  Vitesco Technologies Group AG            3.1            Software Engineer
# 5                        Spotify            3.9          Backend Engineer II
# 6                          Infor            4.0  Associate Software Engineer
# 7          Amerisoft Corporation            5.0          Software Developers
# 8                          WHOOP            3.3         Software Engineer II
# 9                            PFF            4.2        Sr. Software Engineer
#
#                Location  Date                         Salary  Annual Salary  \
# 0          Manassas, VA   8.0   $68K - $94K (Glassdoor est.)        81000.0
# 1                Remote   2.0   $61K - $104K (Employer est.)        82500.0
# 2              Cary, NC   2.0  $95K - $118K (Glassdoor est.)       106500.0
# 3       Los Angeles, CA   2.0   $97K - $145K (Employer est.)       121000.0
# 4            Seguin, TX   2.0  $85K - $108K (Glassdoor est.)        96500.0
# 5          New York, NY   1.0  $123K - $175K (Employer est.)       149000.0
# 6        Alpharetta, GA   7.0   $77K - $94K (Glassdoor est.)        85500.0
# 7  Farmington Hills, MI  30.0  $71K - $100K (Glassdoor est.)        85500.0
# 8            Boston, MA  10.0  $94K - $148K (Glassdoor est.)       121000.0
# 9                Remote   1.0  $147K - $189K (Employer est.)       168000.0
#
#    Estimate Type  Employer est  Glassdoor est
# 0  Glassdoor est         False          False
# 1  Employer est.          True          False
# 2  Glassdoor est         False          False
# 3  Employer est.          True          False
# 4  Glassdoor est         False          False
# 5  Employer est.          True          False
# 6  Glassdoor est         False          False
# 7  Glassdoor est         False          False
# 8  Glassdoor est         False          False
# 9  Employer est.          True          False

# %%
def loc_correction(location):
    parts = location.split(",")
    
    if len(parts) == 2:
        city = parts[0].strip()
        state = parts[1].strip()
        remote = False
        
    elif 'Remote' in location:
        city, state = None, None
        remote = True
        
    else:
        city, state = location, None
        remote = False
        
    return state, city, remote

df['Location'] = df['Location'].astype(str)
df[['state', 'city', 'remote']] = df['Location'].apply( lambda x : pd.Series(loc_correction(x)))

# %%
df
# Out:
#                            Company  Company Score                  Job Title  \
# 0                         ViewSoft            4.8          Software Engineer
# 1                          Workiva            4.3  Software Support Engineer
# 2       Garmin International, Inc.            3.9       C# Software Engineer
# 3                         Snapchat            3.5          Software Engineer
# 4    Vitesco Technologies Group AG            3.1          Software Engineer
# ..                             ...            ...                        ...
# 865                            RXO            NaN          Software Engineer
# 866                        Infosys            NaN          Software Engineer
# 867                      Medtronic            NaN   Senior Software Engineer
# 868                            NaN            NaN    Junior Python Developer
# 869                            NaN            NaN   GUI Software Engineer II
#
#                    Location  Date                         Salary  \
# 0              Manassas, VA   8.0   $68K - $94K (Glassdoor est.)
# 1                    Remote   2.0   $61K - $104K (Employer est.)
# 2                  Cary, NC   2.0  $95K - $118K (Glassdoor est.)
# 3           Los Angeles, CA   2.0   $97K - $145K (Employer est.)
# 4                Seguin, TX   2.0  $85K - $108K (Glassdoor est.)
# ..                      ...   ...                            ...
# 865       San Francisco, CA   6.0                            nan
# 866  Annapolis Junction, MD  18.0                            nan
# 867          Southfield, MI  19.0                            nan
# 868           Charlotte, NC   2.0                            nan
# 869              Boston, MA  10.0                            nan
#
#      Annual Salary  Estimate Type  Employer est  Glassdoor est state  \
# 0          81000.0  Glassdoor est         False          False    VA
# 1          82500.0  Employer est.          True          False  None
# 2         106500.0  Glassdoor est         False          False    NC
# 3         121000.0  Employer est.          True          False    CA
# 4          96500.0  Glassdoor est         False          False    TX
# ..             ...            ...           ...            ...   ...
# 865            NaN  Glassdoor est         False          False    CA
# 866            NaN  Glassdoor est         False          False    MD
# 867            NaN  Glassdoor est         False          False    MI
# 868            NaN  Glassdoor est         False          False    NC
# 869            NaN  Glassdoor est         False          False    MA
#
#                    city  remote
# 0              Manassas   False
# 1                  None    True
# 2                  Cary   False
# 3           Los Angeles   False
# 4                Seguin   False
# ..                  ...     ...
# 865       San Francisco   False
# 866  Annapolis Junction   False
# 867          Southfield   False
# 868           Charlotte   False
# 869              Boston   False
#
# [870 rows x 13 columns]

# %%
data_cleaned = df.drop(columns=[ 'Salary', 'Location'])

data_cleaned.head(10)
# Out:
#                          Company  Company Score                    Job Title  \
# 0                       ViewSoft            4.8            Software Engineer
# 1                        Workiva            4.3    Software Support Engineer
# 2     Garmin International, Inc.            3.9         C# Software Engineer
# 3                       Snapchat            3.5            Software Engineer
# 4  Vitesco Technologies Group AG            3.1            Software Engineer
# 5                        Spotify            3.9          Backend Engineer II
# 6                          Infor            4.0  Associate Software Engineer
# 7          Amerisoft Corporation            5.0          Software Developers
# 8                          WHOOP            3.3         Software Engineer II
# 9                            PFF            4.2        Sr. Software Engineer
#
#    Date  Annual Salary  Estimate Type  Employer est  Glassdoor est state  \
# 0   8.0        81000.0  Glassdoor est         False          False    VA
# 1   2.0        82500.0  Employer est.          True          False  None
# 2   2.0       106500.0  Glassdoor est         False          False    NC
# 3   2.0       121000.0  Employer est.          True          False    CA
# 4   2.0        96500.0  Glassdoor est         False          False    TX
# 5   1.0       149000.0  Employer est.          True          False    NY
# 6   7.0        85500.0  Glassdoor est         False          False    GA
# 7  30.0        85500.0  Glassdoor est         False          False    MI
# 8  10.0       121000.0  Glassdoor est         False          False    MA
# 9   1.0       168000.0  Employer est.          True          False  None
#
#                city  remote
# 0          Manassas   False
# 1              None    True
# 2              Cary   False
# 3       Los Angeles   False
# 4            Seguin   False
# 5          New York   False
# 6        Alpharetta   False
# 7  Farmington Hills   False
# 8            Boston   False
# 9              None    True

# %%
data_cleaned.isna().sum()
# Out:
# Company            2
# Company Score     81
# Job Title          0
# Date               0
# Annual Salary    133
# Estimate Type      0
# Employer est       0
# Glassdoor est      0
# state            139
# city              39
# remote             0
# dtype: int64

# %%
data_cleaned['Company'] = data_cleaned['Company'].fillna('Unknown')
data_cleaned['state'] = data_cleaned['state'].fillna('Unknown')
data_cleaned['city'] = data_cleaned['city'].fillna('Unknown')
data_cleaned['Company Score'] = data_cleaned['Company Score'].fillna(data_cleaned['Company Score'].mean())
data_cleaned['Annual Salary'] = data_cleaned['Annual Salary'].fillna(data_cleaned['Annual Salary'].mean())

# %%
data_cleaned.isna().sum()
# Out:
# Company          0
# Company Score    0
# Job Title        0
# Date             0
# Annual Salary    0
# Estimate Type    0
# Employer est     0
# Glassdoor est    0
# state            0
# city             0
# remote           0
# dtype: int64

# %%
data_cleaned.head(25).groupby(['Company'])['Annual Salary'].mean()
# Out:
# Company
# 7-Eleven, Inc.                   117500.0
# Adobe                             81500.0
# Amerisoft Corporation             85500.0
# Amex                             112500.0
# Athenahealth                     240000.0
# Boston Children's Hospital       137500.0
# Garmin International, Inc.       106500.0
# HealthMine Services, Inc.         66500.0
# Hertz                            179000.0
# Honeywell                        113000.0
# Infor                             85500.0
# Legrand AV                       102500.0
# Megaport                         108500.0
# PFF                              168000.0
# SOFT LABS NA                     106000.0
# Salesforce                       101500.0
# Snapchat                         105000.0
# Spotify                          149000.0
# Summit Technologies, Inc.         68500.0
# The MITRE Corporation            153500.0
# ViewSoft                          81000.0
# Vitesco Technologies Group AG     96500.0
# WHOOP                            121000.0
# Workiva                           82500.0
# Name: Annual Salary, dtype: float64

# %%
data_cleaned.head(25).groupby(['city'])['Annual Salary'].mean()
# Out:
# city
# Aguadilla                 113000.000000
# Alpharetta                 85500.000000
# Bedford                   153500.000000
# Boston                    166166.666667
# Cary                      106500.000000
# Farmington Hills           85500.000000
# Irving                    117500.000000
# Los Angeles               105000.000000
# Manassas                   81000.000000
# Minneapolis-Saint Paul    102500.000000
# New York                  149000.000000
# Northborough              106000.000000
# Plantation                112500.000000
# San Francisco             101500.000000
# San Jose                   81500.000000
# Seattle                   179000.000000
# Seguin                     96500.000000
# Springfield                68500.000000
# Unknown                   105666.666667
# nan                       108500.000000
# Name: Annual Salary, dtype: float64

# %%
avg_salary_by_location = data_cleaned.head(25).groupby(['city'])['Annual Salary'].mean().sort_values()

avg_salary_by_location.plot(kind = 'bar', figsize=(10,5))
plt.title('Average Salary by Location')
plt.xlabel('Average Salary')
plt.ylabel('Location')
plt.show()

# %%
avg_salary_by_location = data_cleaned.head(25).groupby(['Company'])['Annual Salary'].mean().sort_values()

avg_salary_by_location.plot(kind = 'bar', figsize=(10,5), color = 'g')
plt.title('Average Salary by Company')
plt.xlabel('Average Salary')
plt.ylabel('Company')
plt.show()

# %%
avg_salary_by_location = data_cleaned.head(25).groupby(['Job Title'])['Annual Salary'].mean().sort_values()

avg_salary_by_location.plot(kind = 'bar', figsize=(10,5), color = 'r')
plt.title('Average Salary by Job Title')
plt.xlabel('Average Salary')
plt.ylabel('Job Title')
plt.show()

# %%
avg_salary_by_location = data_cleaned.head(25).groupby(['Company'])['Company Score'].mean().sort_values()

avg_salary_by_location.plot(kind = 'bar', figsize=(10,5), color = 'y')
plt.title('Average Company Score by Company')
plt.xlabel('Average Salary')
plt.ylabel('Company Score')
plt.show()

# %%
city_salary=data_cleaned.sample(20).groupby(['city'])['Annual Salary'].mean()

labels = city_salary.index
sizes = city_salary.values
# custom_colors = ['#ff9999', '#ff66b3', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6', '#c2f0c2']

plt.figure(figsize=(8, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Percentage of Average Salary by City')
plt.axis('equal')
plt.show()
